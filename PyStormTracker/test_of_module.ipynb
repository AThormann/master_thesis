# %%
import stormtracker as st
import xarray as xr
import json
import pystormtracker as pst

# %%
st.hodges_tracker(input_file_path='/Users/annasophiamaxen/Desktop/PYTHON/master_thesis/PyStormTracker/vo_NA_feb_04.nc', output_file_name='tracks_feb_04', track_variable='vo')
# Out:
# 'Tracking done'

# %%
tracks = pst.load_tracks('/Users/annasophiamaxen/Desktop/PYTHON/master_thesis/PyStormTracker/tracks_feb_04.trackjson')

# %%
st.plot_tracks(tracks, min_length=10)
